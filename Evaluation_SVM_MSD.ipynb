# %% [markdown]
# # Cross-collection evaluation of SVM baseline in the MSD test set

# %%
# %pylab inline
# %load_ext autoreload
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import csv
import collections
import json
import os

# %% [markdown]
# ## Evaluation strategies
# We consider different strategies for evaluation. These strategies are concerned with the mapping between the classes defined by the classifiers and the classes defined in our generated ground truth. A direct mapping is not possible for any of our classifiers.
#
# We want to know classifier performance given all music in a dataset, as well as its performance when only given the subset of music that it is aimed for:
# * __S1__ Use only recordings whose ground truth has a matching class in the classifier. For example, if a recording is only annotated with the class electronic, and this class does not appear in the classifier model, we discard it.
# * __S2__ Use all recordings in the ground truth and treat recordings from classes that do not exist in the model as an incorrect classification.
#
# Where the ground truth has more than one class for a track we consider different methods of matching these classes to classifiers’ estimates:
#  * __ONLY__: Only use recordings that have one ground-truth genre tag, and discard the rest of the recordings when computing evaluation metrics
#  * __ALL__: When a recording has more than one ground-truth genre, accept an estimate as correct if it matches any of these, even though for the rest of the genres it could be considered a misclassification.
#
#
# ### Duplicates
# As we have observed that duplicate recordings submitted to AcousticBrainz may have inconsistent genre es-
# timates as a result of different low-level descriptors, we consider two ways of dealing with them:
#  * __D1__ Remove all recordings that have duplicates from consideration
#  * __D2__ Treat all instances (recordings) in our data as independent, even if they are the same song.

# %% [markdown]
# # Mappings

# %% [markdown]
# The rosamerica -> our ground truth mapping. We discard the speech class as it has no match in our ground truth

# %%
rosamerica_gt_map = {
    'cla': ['classical'],
    'dan': ['dance'], # We listened to this dataset. It's all eurotrance (subgenre of electronic)
    'hip': ['hip hop'],
    'jaz': ['jazz'],
    'pop': ['pop'],
    'rhy': ['rhythm and blues'],
    'roc': ['rock'],
}

# %% [markdown]
# Tzanetakis groundtruth mapping. We discard disco as there is no clear match to our ground truth (the class in the dataset contains both electronic disco and non-electronic funk/soul-type disco. We are not sure if we should match it to electronic or rhythm and blues. We don't have a separate top-level genre for metal so we map both metal and rock to rock.

# %%
tzanetakis_gt_map = {
    'blu': ['blues'],
    'cla': ['classical'],
    'cou': ['country'],
    'dis': ['disco'], #disco - electronic & acoustic soul
    'hip': ['hip hop'],
    'jaz': ['jazz'],
    'met': ['metal'],
    'pop': ['pop'],
    'reg': ['reggae'], # reggae, in our gt a subgenre of ska
    'roc': ['rock']
}

# %% [markdown]
# Dortmund groundtruth mapping. Both alternative and rock are mapped to rock. folkcountry is mapped to both folk and country.

# %%
dortmund_gt_map = {
    'alternative': ['alternative rock'], # alternative rock is a subgenre of rock
    'blues': ['blues'],
    'electronic': ['electronic'],
    'folkcountry': ['country'],
    'funksoulrnb': ['rhythm and blues'],
    'jazz': ['jazz'],
    'pop': ['pop'],
    'raphiphop': ['hip hop'],
    'rock': ['rock']
}

# %% [markdown]
# ## Evaluation

# %%
import genreeval

ground_truth = "lastfm-audio-genres-clean.json"

ros = ("Rosamerica", 'predictions/msd/svm/rosamerica.json', rosamerica_gt_map)
dor = ("Dortmund", 'predictions/msd/svm/dortmund.json', dortmund_gt_map)
tza = ("Tzanetakis", 'predictions/msd/svm/tzanetakis.json', tzanetakis_gt_map)

res = {}
for name, filename, gtmap in [ros, dor, tza]:
    res[name] = genreeval.run_evaluations(ground_truth, gtmap, filename, name, "Evaluation")[name]
# Out:
# RUNNING EVALUATION: Rosamerica S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16489 complete
#
# RUNNING EVALUATION: Rosamerica S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16489 complete
#
# RUNNING EVALUATION: Rosamerica S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 13756 complete
#
# RUNNING EVALUATION: Rosamerica S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 13756 complete
#
# RUNNING EVALUATION: Rosamerica S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25510 complete
#  [                  0%                  ]  20001 of 25510 complete
#
# RUNNING EVALUATION: Rosamerica S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25510 complete
#  [                  0%                  ]  20001 of 25510 complete
#
# RUNNING EVALUATION: Rosamerica S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16351 complete
#
# RUNNING EVALUATION: Rosamerica S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16351 complete
#
# RUNNING EVALUATION: Dortmund S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 23214 complete
#  [                  0%                  ]  20001 of 23214 complete
#
# RUNNING EVALUATION: Dortmund S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 23214 complete
#  [                  0%                  ]  20001 of 23214 complete
#
# RUNNING EVALUATION: Dortmund S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16878 complete
#
# RUNNING EVALUATION: Dortmund S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16878 complete
#
# RUNNING EVALUATION: Dortmund S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25510 complete
#  [                  0%                  ]  20001 of 25510 complete
#
# RUNNING EVALUATION: Dortmund S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25510 complete
#  [                  0%                  ]  20001 of 25510 complete
#
# RUNNING EVALUATION: Dortmund S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16351 complete
#
# RUNNING EVALUATION: Dortmund S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16351 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 17685 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 17685 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 14929 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 14929 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25510 complete
#  [                  0%                  ]  20001 of 25510 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25510 complete
#  [                  0%                  ]  20001 of 25510 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16351 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16351 complete

# %%
output = ""
from IPython.display import HTML
for classifier in ["Rosamerica", "Dortmund", "Tzanetakis"]:
    output += "<h1>%s</h1>" % classifier
    for strat in ["S1", "S2"]:
        for var in ["ONLY", "ALL"]: #"FIRST"
            for d in ["D1", "D2"]:
                results = res[classifier][strat][var][d]
                results.save("results")
                #fname = "%s.csv" % results.name.lower().replace(" ", "").replace(",", "-")
                #results.confusion_matrix.to_csv(fname)
                output += "<h2>%s</h2>\n" % (results.data['name'], )
                output += "<p><b>Raw accuracy: </b>%s\n" % results.raw_accuracy
                output += "<br><b>Normalised accuracy: </b>%s</p>\n" % results.normalised_accuracy
                output += results.html + "\n\n"
HTML(output)
# Out:
# <h1>Rosamerica</h1><h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>49.74
# <br><b>Normalised accuracy: </b>49.65</p>
# <b>Confusion matrix for Rosamerica S1-ONLY-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">66.99</td><td>0.97</td><td>3.88</td><td>0.0</td><td>9.71</td><td>9.71</td><td>8.74</td></tr>
# <tr><th>dance</th><td>2.04</td><td style="background-color:green">47.26</td><td style="background-color:red">20.51</td><td>0.76</td><td>8.15</td><td>8.41</td><td style="background-color:red">12.87</td></tr>
# <tr><th>hip hop</th><td>0.44</td><td>5.18</td><td style="background-color:green">67.46</td><td>0.15</td><td>2.22</td><td style="background-color:red">19.97</td><td>4.59</td></tr>
# <tr><th>jazz</th><td style="background-color:red">25.62</td><td>0.55</td><td>4.47</td><td style="background-color:green">32.85</td><td>4.85</td><td style="background-color:red">28.26</td><td>3.4</td></tr>
# <tr><th>pop</th><td>7.12</td><td>5.46</td><td>6.35</td><td>1.05</td><td style="background-color:green">26.55</td><td style="background-color:red">30.74</td><td style="background-color:red">22.74</td></tr>
# <tr><th>rhythm and blues</th><td>7.42</td><td>2.82</td><td style="background-color:red">16.81</td><td>3.02</td><td style="background-color:red">17.47</td><td style="background-color:green">44.65</td><td>7.81</td></tr>
# <tr><th>rock</th><td>6.45</td><td>1.48</td><td>4.77</td><td>0.93</td><td>9.05</td><td style="background-color:red">15.49</td><td style="background-color:green">61.83</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>49.74
# <br><b>Normalised accuracy: </b>49.65</p>
# <b>Confusion matrix for Rosamerica S1-ONLY-D2</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">66.99</td><td>0.97</td><td>3.88</td><td>0.0</td><td>9.71</td><td>9.71</td><td>8.74</td></tr>
# <tr><th>dance</th><td>2.04</td><td style="background-color:green">47.26</td><td style="background-color:red">20.51</td><td>0.76</td><td>8.15</td><td>8.41</td><td style="background-color:red">12.87</td></tr>
# <tr><th>hip hop</th><td>0.44</td><td>5.18</td><td style="background-color:green">67.46</td><td>0.15</td><td>2.22</td><td style="background-color:red">19.97</td><td>4.59</td></tr>
# <tr><th>jazz</th><td style="background-color:red">25.62</td><td>0.55</td><td>4.47</td><td style="background-color:green">32.85</td><td>4.85</td><td style="background-color:red">28.26</td><td>3.4</td></tr>
# <tr><th>pop</th><td>7.12</td><td>5.46</td><td>6.35</td><td>1.05</td><td style="background-color:green">26.55</td><td style="background-color:red">30.74</td><td style="background-color:red">22.74</td></tr>
# <tr><th>rhythm and blues</th><td>7.42</td><td>2.82</td><td style="background-color:red">16.81</td><td>3.02</td><td style="background-color:red">17.47</td><td style="background-color:green">44.65</td><td>7.81</td></tr>
# <tr><th>rock</th><td>6.45</td><td>1.48</td><td>4.77</td><td>0.93</td><td>9.05</td><td style="background-color:red">15.49</td><td style="background-color:green">61.83</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>51.58
# <br><b>Normalised accuracy: </b>44.43</p>
# <b>Confusion matrix for Rosamerica S1-ALL-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">58.16</td><td>1.42</td><td>2.84</td><td>1.42</td><td style="background-color:red">13.48</td><td style="background-color:red">13.48</td><td>9.22</td></tr>
# <tr><th>dance</th><td>1.37</td><td style="background-color:green">37.27</td><td style="background-color:red">20.38</td><td>0.82</td><td style="background-color:red">13.25</td><td style="background-color:red">11.32</td><td style="background-color:red">15.58</td></tr>
# <tr><th>hip hop</th><td>0.58</td><td>5.95</td><td style="background-color:green">63.59</td><td>0.35</td><td>3.38</td><td style="background-color:red">20.65</td><td>5.48</td></tr>
# <tr><th>jazz</th><td style="background-color:red">22.95</td><td>0.89</td><td>5.61</td><td style="background-color:green">29.39</td><td>6.26</td><td style="background-color:red">30.64</td><td>4.25</td></tr>
# <tr><th>pop</th><td>5.62</td><td>7.87</td><td>8.08</td><td>1.48</td><td style="background-color:green">25.12</td><td style="background-color:red">26.47</td><td style="background-color:red">25.36</td></tr>
# <tr><th>rhythm and blues</th><td>6.64</td><td>4.64</td><td style="background-color:red">16.96</td><td>3.72</td><td style="background-color:red">19.12</td><td style="background-color:green">40.04</td><td>8.88</td></tr>
# <tr><th>rock</th><td>6.24</td><td>1.82</td><td>5.01</td><td>1.11</td><td style="background-color:red">11.29</td><td style="background-color:red">17.13</td><td style="background-color:green">57.41</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>51.58
# <br><b>Normalised accuracy: </b>44.43</p>
# <b>Confusion matrix for Rosamerica S1-ALL-D2</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">58.16</td><td>1.42</td><td>2.84</td><td>1.42</td><td style="background-color:red">13.48</td><td style="background-color:red">13.48</td><td>9.22</td></tr>
# <tr><th>dance</th><td>1.37</td><td style="background-color:green">37.27</td><td style="background-color:red">20.38</td><td>0.82</td><td style="background-color:red">13.25</td><td style="background-color:red">11.32</td><td style="background-color:red">15.58</td></tr>
# <tr><th>hip hop</th><td>0.58</td><td>5.95</td><td style="background-color:green">63.59</td><td>0.35</td><td>3.38</td><td style="background-color:red">20.65</td><td>5.48</td></tr>
# <tr><th>jazz</th><td style="background-color:red">22.95</td><td>0.89</td><td>5.61</td><td style="background-color:green">29.39</td><td>6.26</td><td style="background-color:red">30.64</td><td>4.25</td></tr>
# <tr><th>pop</th><td>5.62</td><td>7.87</td><td>8.08</td><td>1.48</td><td style="background-color:green">25.12</td><td style="background-color:red">26.47</td><td style="background-color:red">25.36</td></tr>
# <tr><th>rhythm and blues</th><td>6.64</td><td>4.64</td><td style="background-color:red">16.96</td><td>3.72</td><td style="background-color:red">19.12</td><td style="background-color:green">40.04</td><td>8.88</td></tr>
# <tr><th>rock</th><td>6.24</td><td>1.82</td><td>5.01</td><td>1.11</td><td style="background-color:red">11.29</td><td style="background-color:red">17.13</td><td style="background-color:green">57.41</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>25.02
# <br><b>Normalised accuracy: </b>16.98</p>
# <b>Confusion matrix for Rosamerica S2-ONLY-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">71.79</td><td>0.0</td><td>0.0</td><td>0.0</td><td style="background-color:red">12.82</td><td style="background-color:red">10.26</td><td>5.13</td></tr>
# <tr><th>dance</th><td>2.87</td><td style="background-color:green">41.38</td><td style="background-color:red">18.39</td><td>1.15</td><td style="background-color:red">10.92</td><td>8.62</td><td style="background-color:red">16.67</td></tr>
# <tr><th>hip hop</th><td>0.41</td><td>3.89</td><td style="background-color:green">72.19</td><td>0.0</td><td>2.25</td><td style="background-color:red">19.22</td><td>2.04</td></tr>
# <tr><th>jazz</th><td style="background-color:red">26.87</td><td>0.37</td><td>3.59</td><td style="background-color:green">36.8</td><td>4.54</td><td style="background-color:red">25.24</td><td>2.59</td></tr>
# <tr><th>pop</th><td>6.77</td><td>5.1</td><td>6.27</td><td>1.09</td><td
