# %% [markdown]
# # Cross-collection evaluation of VGG transfer learning model in the MSD test set

# %%
# %pylab inline
# %load_ext autoreload
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import csv
import collections
import json
import os

# %% [markdown]
# ## Evaluation strategies
# We consider different strategies for evaluation. These strategies are concerned with the mapping between the classes defined by the classifiers and the classes defined in our generated ground truth. A direct mapping is not possible for any of our classifiers.
#
# We want to know classifier performance given all music in a dataset, as well as its performance when only given the subset of music that it is aimed for:
# * __S1__ Use only recordings whose ground truth has a matching class in the classifier. For example, if a recording is only annotated with the class electronic, and this class does not appear in the classifier model, we discard it.
# * __S2__ Use all recordings in the ground truth and treat recordings from classes that do not exist in the model as an incorrect classification.
#
# Where the ground truth has more than one class for a track we consider different methods of matching these classes to classifiers’ estimates:
#  * __ONLY__: Only use recordings that have one ground-truth genre tag, and discard the rest of the recordings when computing evaluation metrics
#  * __ALL__: When a recording has more than one ground-truth genre, accept an estimate as correct if it matches any of these, even though for the rest of the genres it could be considered a misclassification.
#
#
# ### Duplicates
# As we have observed that duplicate recordings submitted to AcousticBrainz may have inconsistent genre es-
# timates as a result of different low-level descriptors, we consider two ways of dealing with them:
#  * __D1__ Remove all recordings that have duplicates from consideration
#  * __D2__ Treat all instances (recordings) in our data as independent, even if they are the same song.

# %% [markdown]
# # Mappings

# %% [markdown]
# The rosamerica -> our ground truth mapping. We discard the speech class as it has no match in our ground truth

# %%
rosamerica_gt_map = {
    'cla': ['classical'],
    'dan': ['dance'], # We listened to this dataset. It's all eurotrance (subgenre of electronic)
    'hip': ['hip hop'],
    'jaz': ['jazz'],
    'pop': ['pop'],
    'rhy': ['rhythm and blues'],
    'roc': ['rock'],
}

# %% [markdown]
# Tzanetakis groundtruth mapping. We discard disco as there is no clear match to our ground truth (the class in the dataset contains both electronic disco and non-electronic funk/soul-type disco. We are not sure if we should match it to electronic or rhythm and blues. We don't have a separate top-level genre for metal so we map both metal and rock to rock.

# %%
tzanetakis_gt_map = {
    'blu': ['blues'],
    'cla': ['classical'],
    'cou': ['country'],
    'dis': ['disco'], #disco - electronic & acoustic soul
    'hip': ['hip hop'],
    'jaz': ['jazz'],
    'met': ['metal'],
    'pop': ['pop'],
    'reg': ['reggae'], # reggae, in our gt a subgenre of ska
    'roc': ['rock']
}

# %% [markdown]
# Dortmund groundtruth mapping. Both alternative and rock are mapped to rock. folkcountry is mapped to both folk and country.

# %%
dortmund_gt_map = {
    'alternative': ['alternative rock'], # alternative rock is a subgenre of rock
    'blues': ['blues'],
    'electronic': ['electronic'],
    'folkcountry': [ 'country'],
    'funksoulrnb': ['rhythm and blues'],
    'jazz': ['jazz'],
    'pop': ['pop'],
    'raphiphop': ['hip hop'],
    'rock': ['rock']
}

# %% [markdown]
# ## Evaluation

# %%
import genreeval

ground_truth = "lastfm-audio-genres-clean.json"

ros = ("Rosamerica", "predictions/msd/lastfm-test_vgg-tl-MSD_rosamerica.json", rosamerica_gt_map)
dor = ("Dortmund", "predictions/msd/lastfm-test_vgg-tl-MSD_dortmund.json", dortmund_gt_map)
tza = ("Tzanetakis", "predictions/msd/lastfm-test_vgg-tl-MSD_tzanetakis.json", tzanetakis_gt_map)

res = {}
for name, filename, gtmap in [ros, dor, tza]:
    res[name] = genreeval.run_evaluations(ground_truth, gtmap, filename, name, "Evaluation")[name]
# Out:
# RUNNING EVALUATION: Rosamerica S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16499 complete
#
# RUNNING EVALUATION: Rosamerica S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16499 complete
#
# RUNNING EVALUATION: Rosamerica S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 13766 complete
#
# RUNNING EVALUATION: Rosamerica S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 13766 complete
#
# RUNNING EVALUATION: Rosamerica S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Rosamerica S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Rosamerica S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Rosamerica S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Dortmund S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 23229 complete
#  [                  0%                  ]  20001 of 23229 complete
#
# RUNNING EVALUATION: Dortmund S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 23229 complete
#  [                  0%                  ]  20001 of 23229 complete
#
# RUNNING EVALUATION: Dortmund S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16889 complete
#
# RUNNING EVALUATION: Dortmund S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16889 complete
#
# RUNNING EVALUATION: Dortmund S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Dortmund S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Dortmund S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Dortmund S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 17698 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 17698 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 14941 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 14941 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete

# %%
output = ""
from IPython.display import HTML
for classifier in ["Rosamerica", "Dortmund", "Tzanetakis"]:
    output += "<h1>%s</h1>" % classifier
    for strat in ["S1", "S2"]:
        for var in ["ONLY", "ALL"]: #"FIRST"
            for d in ["D1", "D2"]:
                results = res[classifier][strat][var][d]
                results.save("results")
                #fname = "%s.csv" % results.name.lower().replace(" ", "").replace(",", "-")
                #results.confusion_matrix.to_csv(fname)
                output += "<h2>%s</h2>\n" % (results.data['name'], )
                output += "<p><b>Raw accuracy: </b>%s\n" % results.raw_accuracy
                output += "<br><b>Normalised accuracy: </b>%s</p>\n" % results.normalised_accuracy
                output += results.html + "\n\n"
HTML(output)
# Out:
# <h1>Rosamerica</h1><h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>48.19
# <br><b>Normalised accuracy: </b>56.89</p>
# <b>Confusion matrix for Rosamerica S1-ONLY-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">66.35</td><td>0.96</td><td>3.85</td><td>1.92</td><td style="background-color:red">15.38</td><td style="background-color:red">10.58</td><td>0.96</td></tr>
# <tr><th>dance</th><td>0.38</td><td style="background-color:green">60.99</td><td style="background-color:red">13.47</td><td>0.13</td><td style="background-color:red">19.95</td><td>4.32</td><td>0.76</td></tr>
# <tr><th>hip hop</th><td>0.15</td><td>2.2</td><td style="background-color:green">80.62</td><td>0.29</td><td style="background-color:red">11.01</td><td>3.82</td><td>1.91</td></tr>
# <tr><th>jazz</th><td>9.05</td><td>1.51</td><td>2.1</td><td style="background-color:green">49.62</td><td style="background-color:red">27.03</td><td>9.35</td><td>1.34</td></tr>
# <tr><th>pop</th><td>2.31</td><td>6.39</td><td>4.63</td><td>2.09</td><td style="background-color:green">63.49</td><td style="background-color:red">15.58</td><td>5.51</td></tr>
# <tr><th>rhythm and blues</th><td>1.05</td><td>2.55</td><td style="background-color:red">11.5</td><td>3.2</td><td style="background-color:red">43.89</td><td style="background-color:green">36.25</td><td>1.57</td></tr>
# <tr><th>rock</th><td>2.82</td><td>1.63</td><td>3.46</td><td>1.29</td><td style="background-color:red">42.05</td><td>7.85</td><td style="background-color:green">40.91</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>48.19
# <br><b>Normalised accuracy: </b>56.89</p>
# <b>Confusion matrix for Rosamerica S1-ONLY-D2</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">66.35</td><td>0.96</td><td>3.85</td><td>1.92</td><td style="background-color:red">15.38</td><td style="background-color:red">10.58</td><td>0.96</td></tr>
# <tr><th>dance</th><td>0.38</td><td style="background-color:green">60.99</td><td style="background-color:red">13.47</td><td>0.13</td><td style="background-color:red">19.95</td><td>4.32</td><td>0.76</td></tr>
# <tr><th>hip hop</th><td>0.15</td><td>2.2</td><td style="background-color:green">80.62</td><td>0.29</td><td style="background-color:red">11.01</td><td>3.82</td><td>1.91</td></tr>
# <tr><th>jazz</th><td>9.05</td><td>1.51</td><td>2.1</td><td style="background-color:green">49.62</td><td style="background-color:red">27.03</td><td>9.35</td><td>1.34</td></tr>
# <tr><th>pop</th><td>2.31</td><td>6.39</td><td>4.63</td><td>2.09</td><td style="background-color:green">63.49</td><td style="background-color:red">15.58</td><td>5.51</td></tr>
# <tr><th>rhythm and blues</th><td>1.05</td><td>2.55</td><td style="background-color:red">11.5</td><td>3.2</td><td style="background-color:red">43.89</td><td style="background-color:green">36.25</td><td>1.57</td></tr>
# <tr><th>rock</th><td>2.82</td><td>1.63</td><td>3.46</td><td>1.29</td><td style="background-color:red">42.05</td><td>7.85</td><td style="background-color:green">40.91</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>51.46
# <br><b>Normalised accuracy: </b>49.57</p>
# <b>Confusion matrix for Rosamerica S1-ALL-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">56.34</td><td>1.41</td><td>3.52</td><td>2.11</td><td style="background-color:red">19.01</td><td style="background-color:red">16.2</td><td>1.41</td></tr>
# <tr><th>dance</th><td>0.21</td><td style="background-color:green">47.22</td><td style="background-color:red">16.38</td><td>0.34</td><td style="background-color:red">28.24</td><td>6.85</td><td>0.75</td></tr>
# <tr><th>hip hop</th><td>0.23</td><td>2.43</td><td style="background-color:green">75.58</td><td>0.23</td><td style="background-color:red">12.5</td><td>6.25</td><td>2.78</td></tr>
# <tr><th>jazz</th><td>8.05</td><td>1.83</td><td>3.0</td><td style="background-color:green">43.72</td><td style="background-color:red">30.7</td><td style="background-color:red">11.12</td><td>1.59</td></tr>
# <tr><th>pop</th><td>1.91</td><td>9.31</td><td>7.71</td><td>1.6</td><td style="background-color:green">57.49</td><td style="background-color:red">15.03</td><td>6.93</td></tr>
# <tr><th>rhythm and blues</th><td>1.2</td><td>4.07</td><td style="background-color:red">14.35</td><td>3.75</td><td style="background-color:red">44.5</td><td style="background-color:green">30.58</td><td>1.56</td></tr>
# <tr><th>rock</th><td>2.62</td><td>1.95</td><td>3.97</td><td>1.3</td><td style="background-color:red">45.08</td><td>9.03</td><td style="background-color:green">36.05</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>51.46
# <br><b>Normalised accuracy: </b>49.57</p>
# <b>Confusion matrix for Rosamerica S1-ALL-D2</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">56.34</td><td>1.41</td><td>3.52</td><td>2.11</td><td style="background-color:red">19.01</td><td style="background-color:red">16.2</td><td>1.41</td></tr>
# <tr><th>dance</th><td>0.21</td><td style="background-color:green">47.22</td><td style="background-color:red">16.38</td><td>0.34</td><td style="background-color:red">28.24</td><td>6.85</td><td>0.75</td></tr>
# <tr><th>hip hop</th><td>0.23</td><td>2.43</td><td style="background-color:green">75.58</td><td>0.23</td><td style="background-color:red">12.5</td><td>6.25</td><td>2.78</td></tr>
# <tr><th>jazz</th><td>8.05</td><td>1.83</td><td>3.0</td><td style="background-color:green">43.72</td><td style="background-color:red">30.7</td><td style="background-color:red">11.12</td><td>1.59</td></tr>
# <tr><th>pop</th><td>1.91</td><td>9.31</td><td>7.71</td><td>1.6</td><td style="background-color:green">57.49</td><td style="background-color:red">15.03</td><td>6.93</td></tr>
# <tr><th>rhythm and blues</th><td>1.2</td><td>4.07</td><td style="background-color:red">14.35</td><td>3.75</td><td style="background-color:red">44.5</td><td style="background-color:green">30.58</td><td>1.56</td></tr>
# <tr><th>rock</th><td>2.62</td><td>1.95</td><td>3.97</td><td>1.3</td><td style="background-color:red">45.08</td><td>9.03</td><td style="background-color:green">36.05</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>25.61
# <br><b>Normalised accuracy: </b>19.25</p>
# <b>Confusion matrix for Rosamerica S2-ONLY-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">69.23</td><td>0.0</td><td>0.0</td><td>5.13</td><td style="background-color:red">12.82</td><td style="background-color:red">12.82</td><td>0.0</td></tr>
# <tr><th>dance</th><td>0.57</td><td style="background-color:green">50.0</td><td style="background-color:red">16.67</td><td>0.0</td><td style="background-color:red">26.44</td><td>4.6</td><td>1.72</td></tr>
# <tr><th>hip hop</th><td>0.0</td><td>0.81</td><td style="background-color:green">87.6</td><td>0.2</td><td>8.33</td><td>2.64</td><td>0.41</td></tr>
# <tr><th>jazz</th><td>9.34</td><td>1.4</td><td>1.66</td><td style="background-color:green">55.45</td><td style="background-color:red">22.72</td><td>8.51</td><td>0.93</td></tr>
# <tr><th>pop</th><td>1.67</td><td>5.83</td><td>4.33</td><td>1.42</td><td style="background-color:green">63.53</td><td style="background-color:red">16.57</td><td>6.66</td></tr>
# <tr><th>rhythm and blues</th><td>0.98</td><td>1.95</td><td style="background-color:red">11.32</td><td>2.61</td><td style="background-color:red">43.89</td><td style="background-color:green">37.62</td><td>1.63</td></tr>
# <tr><th>rock</th><td>2.6</td><td
