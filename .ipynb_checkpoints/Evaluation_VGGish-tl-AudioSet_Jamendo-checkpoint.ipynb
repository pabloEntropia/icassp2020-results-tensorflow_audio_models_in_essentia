# %% [markdown]
# # Cross-collection evaluation of VGGish transfer learning model in the MTG-Jamendo test set

# %%
# %pylab inline
# %load_ext autoreload
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import csv
import collections
import json
import os

# %% [markdown]
# ## Evaluation strategies
# We consider different strategies for evaluation. These strategies are concerned with the mapping between the classes defined by the classifiers and the classes defined in our generated ground truth. A direct mapping is not possible for any of our classifiers.
#
# We want to know classifier performance given all music in a dataset, as well as its performance when only given the subset of music that it is aimed for:
# * __S1__ Use only recordings whose ground truth has a matching class in the classifier. For example, if a recording is only annotated with the class electronic, and this class does not appear in the classifier model, we discard it.
# * __S2__ Use all recordings in the ground truth and treat recordings from classes that do not exist in the model as an incorrect classification.
#
# Where the ground truth has more than one class for a track we consider different methods of matching these classes to classifiers’ estimates:
#  * __ONLY__: Only use recordings that have one ground-truth genre tag, and discard the rest of the recordings when computing evaluation metrics
#  * __ALL__: When a recording has more than one ground-truth genre, accept an estimate as correct if it matches any of these, even though for the rest of the genres it could be considered a misclassification.
#
#
# ### Duplicates
# As we have observed that duplicate recordings submitted to AcousticBrainz may have inconsistent genre es-
# timates as a result of different low-level descriptors, we consider two ways of dealing with them:
#  * __D1__ Remove all recordings that have duplicates from consideration
#  * __D2__ Treat all instances (recordings) in our data as independent, even if they are the same song.

# %% [markdown]
# # Mappings

# %% [markdown]
# The rosamerica -> our ground truth mapping. We discard the speech class as it has no match in our ground truth

# %%
rosamerica_gt_map = {
    'cla': ['classical'],
    'dan': ['dance'], # We listened to this dataset. It's all eurotrance (subgenre of electronic)
    'hip': ['hip hop'],
    'jaz': ['jazz'],
    'pop': ['pop'],
    'rhy': ['rhythm and blues'],
    'roc': ['rock'],
}

# %% [markdown]
# Tzanetakis groundtruth mapping. We discard disco as there is no clear match to our ground truth (the class in the dataset contains both electronic disco and non-electronic funk/soul-type disco. We are not sure if we should match it to electronic or rhythm and blues. We don't have a separate top-level genre for metal so we map both metal and rock to rock.

# %%
tzanetakis_gt_map = {
    'blu': ['blues'],
    'cla': ['classical'],
    'cou': ['country'],
    'dis': ['disco'], #disco - electronic & acoustic soul
    'hip': ['hip hop'],
    'jaz': ['jazz'],
    'met': ['metal'],
    'pop': ['pop'],
    'reg': ['reggae'], # reggae, in our gt a subgenre of ska
    'roc': ['rock']
}

# %% [markdown]
# Dortmund groundtruth mapping. Both alternative and rock are mapped to rock. folkcountry is mapped to both folk and country.

# %%
dortmund_gt_map = {
    'alternative': ['alternative rock'], # alternative rock is a subgenre of rock
    'blues': ['blues'],
    'electronic': ['electronic'],
    'folkcountry': ['country'],
    'funksoulrnb': ['rhythm and blues'],
    'jazz': ['jazz'],
    'pop': ['pop'],
    'raphiphop': ['hip hop'],
    'rock': ['rock']
}

# %% [markdown]
# ## Evaluation

# %%
import genreeval

ground_truth = "jamendo-genres-clean.json"

ros = ("Rosamerica", 'predictions/jamendo/vggish_tl_audioset/genre_rosamerica/jamendo_test_split0_genre_rosamerica_predicted_classes.json', rosamerica_gt_map)
dor = ("Dortmund", "predictions/jamendo/vggish_tl_audioset/genre_dortmund/jamendo_test_split0_genre_dortmund_predicted_classes.json", dortmund_gt_map)
tza = ("Tzanetakis", "predictions/jamendo/vggish_tl_audioset/genre_tzanetakis/jamendo_test_split0_genre_tzanetakis_predicted_classes.json", tzanetakis_gt_map)

res = {}
for name, filename, gtmap in [ros, dor, tza]:
    res[name] = genreeval.run_evaluations(ground_truth, gtmap, filename, name, "Evaluation")[name]
# Out:
# RUNNING EVALUATION: Rosamerica S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ALL - D1
#  [                  0%                  ]
#
# RUNNING EVALUATION: Rosamerica S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ALL - D2
#  [                  0%                  ]
#
# RUNNING EVALUATION: Rosamerica S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ONLY - D1
#  [                  0%                  ]
#
# RUNNING EVALUATION: Rosamerica S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ONLY - D2
#  [                  0%                  ]
#
# RUNNING EVALUATION: Rosamerica S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 10688 complete
#
# RUNNING EVALUATION: Rosamerica S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 10688 complete
#
# RUNNING EVALUATION: Rosamerica S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ONLY - D1
#  [                  0%                  ]
#
# RUNNING EVALUATION: Rosamerica S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ONLY - D2
#  [                  0%                  ]
#
# RUNNING EVALUATION: Dortmund S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ALL - D1
#  [                  0%                  ]
#
# RUNNING EVALUATION: Dortmund S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ALL - D2
#  [                  0%                  ]
#
# RUNNING EVALUATION: Dortmund S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ONLY - D1
#  [                  0%                  ]
#
# RUNNING EVALUATION: Dortmund S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ONLY - D2
#  [                  0%                  ]
#
# RUNNING EVALUATION: Dortmund S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 10688 complete
#
# RUNNING EVALUATION: Dortmund S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 10688 complete
#
# RUNNING EVALUATION: Dortmund S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ONLY - D1
#  [                  0%                  ]
#
# RUNNING EVALUATION: Dortmund S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ONLY - D2
#  [                  0%                  ]
#
# RUNNING EVALUATION: Tzanetakis S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ALL - D1
#  [                  0%                  ]
#
# RUNNING EVALUATION: Tzanetakis S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ALL - D2
#  [                  0%                  ]
#
# RUNNING EVALUATION: Tzanetakis S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ONLY - D1
#  [                  0%                  ]
#
# RUNNING EVALUATION: Tzanetakis S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ONLY - D2
#  [                  0%                  ]
#
# RUNNING EVALUATION: Tzanetakis S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 10688 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 10688 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ONLY - D1
#  [                  0%                  ]
#
# RUNNING EVALUATION: Tzanetakis S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ONLY - D2
#  [                  0%                  ]

# %%
output = ""
from IPython.display import HTML
for classifier in ["Rosamerica", "Dortmund", "Tzanetakis"]:
    output += "<h1>%s</h1>" % classifier
    for strat in ["S1", "S2"]:
        for var in ["ONLY", "ALL"]: #"FIRST"
            for d in ["D1", "D2"]:
                results = res[classifier][strat][var][d]
                results.save("results")
                #fname = "%s.csv" % results.name.lower().replace(" ", "").replace(",", "-")
                #results.confusion_matrix.to_csv(fname)
                output += "<h2>%s</h2>\n" % (results.data['name'], )
                output += "<p><b>Raw accuracy: </b>%s\n" % results.raw_accuracy
                output += "<br><b>Normalised accuracy: </b>%s</p>\n" % results.normalised_accuracy
                output += results.html + "\n\n"
HTML(output)
# Out:
# <h1>Rosamerica</h1><h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>44.54
# <br><b>Normalised accuracy: </b>48.73</p>
# <b>Confusion matrix for Rosamerica S1-ONLY-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">33.51</td><td style="background-color:red">17.95</td><td>0.8</td><td style="background-color:red">44.47</td><td>0.97</td><td>2.21</td><td>0.09</td></tr>
# <tr><th>dance</th><td>0.26</td><td style="background-color:green">92.09</td><td>3.32</td><td>1.53</td><td>1.53</td><td>1.02</td><td>0.26</td></tr>
# <tr><th>hip hop</th><td>0.2</td><td style="background-color:red">12.3</td><td style="background-color:green">79.69</td><td>3.71</td><td>2.93</td><td>1.17</td><td>0.0</td></tr>
# <tr><th>jazz</th><td>1.28</td><td>7.35</td><td>7.03</td><td style="background-color:green">70.29</td><td>9.9</td><td>3.19</td><td>0.96</td></tr>
# <tr><th>pop</th><td>0.42</td><td style="background-color:red">15.63</td><td>6.4</td><td style="background-color:red">41.13</td><td style="background-color:green">19.31</td><td style="background-color:red">13.43</td><td>3.67</td></tr>
# <tr><th>rhythm and blues</th><td>0.0</td><td style="background-color:red">19.35</td><td style="background-color:red">37.63</td><td style="background-color:red">17.2</td><td style="background-color:red">16.13</td><td style="background-color:green">6.45</td><td>3.23</td></tr>
# <tr><th>rock</th><td>0.1</td><td>8.88</td><td>4.24</td><td style="background-color:red">14.88</td><td style="background-color:red">20.56</td><td style="background-color:red">11.57</td><td style="background-color:green">39.77</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>44.54
# <br><b>Normalised accuracy: </b>48.73</p>
# <b>Confusion matrix for Rosamerica S1-ONLY-D2</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">33.51</td><td style="background-color:red">17.95</td><td>0.8</td><td style="background-color:red">44.47</td><td>0.97</td><td>2.21</td><td>0.09</td></tr>
# <tr><th>dance</th><td>0.26</td><td style="background-color:green">92.09</td><td>3.32</td><td>1.53</td><td>1.53</td><td>1.02</td><td>0.26</td></tr>
# <tr><th>hip hop</th><td>0.2</td><td style="background-color:red">12.3</td><td style="background-color:green">79.69</td><td>3.71</td><td>2.93</td><td>1.17</td><td>0.0</td></tr>
# <tr><th>jazz</th><td>1.28</td><td>7.35</td><td>7.03</td><td style="background-color:green">70.29</td><td>9.9</td><td>3.19</td><td>0.96</td></tr>
# <tr><th>pop</th><td>0.42</td><td style="background-color:red">15.63</td><td>6.4</td><td style="background-color:red">41.13</td><td style="background-color:green">19.31</td><td style="background-color:red">13.43</td><td>3.67</td></tr>
# <tr><th>rhythm and blues</th><td>0.0</td><td style="background-color:red">19.35</td><td style="background-color:red">37.63</td><td style="background-color:red">17.2</td><td style="background-color:red">16.13</td><td style="background-color:green">6.45</td><td>3.23</td></tr>
# <tr><th>rock</th><td>0.1</td><td>8.88</td><td>4.24</td><td style="background-color:red">14.88</td><td style="background-color:red">20.56</td><td style="background-color:red">11.57</td><td style="background-color:green">39.77</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>48.33
# <br><b>Normalised accuracy: </b>47.99</p>
# <b>Confusion matrix for Rosamerica S1-ALL-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">40.29</td><td style="background-color:red">14.48</td><td>0.89</td><td style="background-color:red">40.29</td><td>1.07</td><td>2.62</td><td>0.36</td></tr>
# <tr><th>dance</th><td>0.19</td><td style="background-color:green">83.85</td><td>5.58</td><td>2.5</td><td>6.15</td><td>1.35</td><td>0.38</td></tr>
# <tr><th>hip hop</th><td>0.15</td><td style="background-color:red">11.71</td><td style="background-color:green">78.89</td><td>4.01</td><td>4.31</td><td>0.92</td><td>0.0</td></tr>
# <tr><th>jazz</th><td>1.0</td><td>6.59</td><td>8.98</td><td style="background-color:green">67.47</td><td>7.78</td><td>4.19</td><td>3.99</td></tr>
# <tr><th>pop</th><td>0.4</td><td style="background-color:red">14.76</td><td>7.15</td><td style="background-color:red">31.53</td><td style="background-color:green">22.42</td><td style="background-color:red">13.83</td><td>9.91</td></tr>
# <tr><th>rhythm and blues</th><td>0.0</td><td style="background-color:red">10.47</td><td style="background-color:red">44.56</td><td style="background-color:red">11.29</td><td style="background-color:red">17.86</td><td style="background-color:green">6.78</td><td>9.03</td></tr>
# <tr><th>rock</th><td>0.15</td><td>8.1</td><td>4.73</td><td style="background-color:red">14.3</td><td style="background-color:red">23.96</td><td style="background-color:red">12.54</td><td style="background-color:green">36.21</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>48.33
# <br><b>Normalised accuracy: </b>47.99</p>
# <b>Confusion matrix for Rosamerica S1-ALL-D2</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">40.29</td><td style="background-color:red">14.48</td><td>0.89</td><td style="background-color:red">40.29</td><td>1.07</td><td>2.62</td><td>0.36</td></tr>
# <tr><th>dance</th><td>0.19</td><td style="background-color:green">83.85</td><td>5.58</td><td>2.5</td><td>6.15</td><td>1.35</td><td>0.38</td></tr>
# <tr><th>hip hop</th><td>0.15</td><td style="background-color:red">11.71</td><td style="background-color:green">78.89</td><td>4.01</td><td>4.31</td><td>0.92</td><td>0.0</td></tr>
# <tr><th>jazz</th><td>1.0</td><td>6.59</td><td>8.98</td><td style="background-color:green">67.47</td><td>7.78</td><td>4.19</td><td>3.99</td></tr>
# <tr><th>pop</th><td>0.4</td><td style="background-color:red">14.76</td><td>7.15</td><td style="background-color:red">31.53</td><td style="background-color:green">22.42</td><td style="background-color:red">13.83</td><td>9.91</td></tr>
# <tr><th>rhythm and blues</th><td>0.0</td><td style="background-color:red">10.47</td><td style="background-color:red">44.56</td><td style="background-color:red">11.29</td><td style="background-color:red">17.86</td><td style="background-color:green">6.78</td><td>9.03</td></tr>
# <tr><th>rock</th><td>0.15</td><td>8.1</td><td>4.73</td><td style="background-color:red">14.3</td><td style="background-color:red">23.96</td><td style="background-color:red">12.54</td><td style="background-color:green">36.21</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>20.7
# <br><b>Normalised accuracy: </b>19.89</p>
# <b>Confusion matrix for Rosamerica S2-ONLY-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">34.45</td><td>4.78</td><td>0.8</td><td style="background-color:red">58.53</td><td>0.16</td><td>1.28</td><td>0.0</td></tr>
# <tr><th>dance</th><td>2.78</td><td style="background-color:green">80.56</td><td style="background-color:red">13.89</td><td>2.78</td><td>0.0</td><td>0.0</td><td>0.0</td></tr>
# <tr><th>hip hop</th><td>0.0</td><td>6.88</td><td style="background-color:green">90.26</td><td>1.15</td><td>1.43</td><td>0.29</td><td>0.0</td></tr>
# <tr><th>jazz</th><td>1.42</td><td>3.55</td><td>4.96</td><td style="background-color:green">83.69</td><td>4.96</td><td>1.42</td><td>0.0</td></tr>
# <tr><th>pop</th><td>0.0</td><td>4.58</td><td>5.54</td><td style="background-color:red">49.16</td><td style="background-color:green">21.45</td><td style="background-color:red">14.94</td><td>4.34</td></tr>
# <tr><th>rhythm and blu
