# %% [markdown]
# # Cross-collection evaluation of MusiCNN transfer learning model in the MSD test set

# %%
# %pylab inline
# %load_ext autoreload
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import csv
import collections
import json
import os

# %% [markdown]
# ## Evaluation strategies
# We consider different strategies for evaluation. These strategies are concerned with the mapping between the classes defined by the classifiers and the classes defined in our generated ground truth. A direct mapping is not possible for any of our classifiers.
#
# We want to know classifier performance given all music in a dataset, as well as its performance when only given the subset of music that it is aimed for:
# * __S1__ Use only recordings whose ground truth has a matching class in the classifier. For example, if a recording is only annotated with the class electronic, and this class does not appear in the classifier model, we discard it.
# * __S2__ Use all recordings in the ground truth and treat recordings from classes that do not exist in the model as an incorrect classification.
#
# Where the ground truth has more than one class for a track we consider different methods of matching these classes to classifiers’ estimates:
#  * __ONLY__: Only use recordings that have one ground-truth genre tag, and discard the rest of the recordings when computing evaluation metrics
#  * __ALL__: When a recording has more than one ground-truth genre, accept an estimate as correct if it matches any of these, even though for the rest of the genres it could be considered a misclassification.
#
#
# ### Duplicates
# As we have observed that duplicate recordings submitted to AcousticBrainz may have inconsistent genre es-
# timates as a result of different low-level descriptors, we consider two ways of dealing with them:
#  * __D1__ Remove all recordings that have duplicates from consideration
#  * __D2__ Treat all instances (recordings) in our data as independent, even if they are the same song.

# %% [markdown]
# # Mappings

# %% [markdown]
# The rosamerica -> our ground truth mapping. We discard the speech class as it has no match in our ground truth

# %%
rosamerica_gt_map = {
    'cla': ['classical'],
    'dan': ['dance'], # We listened to this dataset. It's all eurotrance (subgenre of electronic)
    'hip': ['hip hop'],
    'jaz': ['jazz'],
    'pop': ['pop'],
    'rhy': ['rhythm and blues'],
    'roc': ['rock'],
}

# %% [markdown]
# Tzanetakis groundtruth mapping. We discard disco as there is no clear match to our ground truth (the class in the dataset contains both electronic disco and non-electronic funk/soul-type disco. We are not sure if we should match it to electronic or rhythm and blues. We don't have a separate top-level genre for metal so we map both metal and rock to rock.

# %%
tzanetakis_gt_map = {
    'blu': ['blues'],
    'cla': ['classical'],
    'cou': ['country'],
    'dis': ['disco'], #disco - electronic & acoustic soul
    'hip': ['hip hop'],
    'jaz': ['jazz'],
    'met': ['metal'],
    'pop': ['pop'],
    'reg': ['reggae'], # reggae, in our gt a subgenre of ska
    'roc': ['rock']
}

# %% [markdown]
# Dortmund groundtruth mapping. Both alternative and rock are mapped to rock. folkcountry is mapped to both folk and country.

# %%
dortmund_gt_map = {
    'alternative': ['alternative rock'], # alternative rock is a subgenre of rock
    'blues': ['blues'],
    'electronic': ['electronic'],
    'folkcountry': ['country'],
    'funksoulrnb': ['rhythm and blues'],
    'jazz': ['jazz'],
    'pop': ['pop'],
    'raphiphop': ['hip hop'],
    'rock': ['rock']
}

# %% [markdown]
# ## Evaluation

# %%
import genreeval

ground_truth = "lastfm-audio-genres-clean.json"

ros = ("Rosamerica", "predictions/msd/lastfm-test_musicnn-tl-MSD_rosamerica.json", rosamerica_gt_map)
dor = ("Dortmund", "predictions/msd/lastfm-test_musicnn-tl-MSD_dortmund.json", dortmund_gt_map)
tza = ("Tzanetakis", "predictions/msd/lastfm-test_musicnn-tl-MSD_tzanetakis.json", tzanetakis_gt_map)
# magd = ("MSD All Music Dataset", "acousticbrainz-magd-estimates.csv", magd_gt_map)
# tagt = ("Tagtraum", "acousticbrainz-tagtraum-estimates.csv", tagt_gt_map)

res = {}
for name, filename, gtmap in [ros, dor, tza]:
    res[name] = genreeval.run_evaluations(ground_truth, gtmap, filename, name, "Evaluation")[name]
# Out:
# RUNNING EVALUATION: Rosamerica S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16499 complete
#
# RUNNING EVALUATION: Rosamerica S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16499 complete
#
# RUNNING EVALUATION: Rosamerica S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 13766 complete
#
# RUNNING EVALUATION: Rosamerica S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 13766 complete
#
# RUNNING EVALUATION: Rosamerica S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Rosamerica S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Rosamerica S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Rosamerica S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Dortmund S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 23229 complete
#  [                  0%                  ]  20001 of 23229 complete
#
# RUNNING EVALUATION: Dortmund S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 23229 complete
#  [                  0%                  ]  20001 of 23229 complete
#
# RUNNING EVALUATION: Dortmund S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16889 complete
#
# RUNNING EVALUATION: Dortmund S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16889 complete
#
# RUNNING EVALUATION: Dortmund S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Dortmund S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Dortmund S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Dortmund S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 17698 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 17698 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 14941 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 14941 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete

# %%
output = ""
from IPython.display import HTML
for classifier in ["Rosamerica", "Dortmund", "Tzanetakis"]:
    output += "<h1>%s</h1>" % classifier
    for strat in ["S1", "S2"]:
        for var in ["ONLY", "ALL"]: #"FIRST"
            for d in ["D1", "D2"]:
                results = res[classifier][strat][var][d]
                results.save("results")
                #fname = "%s.csv" % results.name.lower().replace(" ", "").replace(",", "-")
                #results.confusion_matrix.to_csv(fname)
                output += "<h2>%s</h2>\n" % (results.data['name'], )
                output += "<p><b>Raw accuracy: </b>%s\n" % results.raw_accuracy
                output += "<br><b>Normalised accuracy: </b>%s</p>\n" % results.normalised_accuracy
                output += results.html + "\n\n"
HTML(output)
# Out:
# <h1>Rosamerica</h1><h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>47.25
# <br><b>Normalised accuracy: </b>59.83</p>
# <b>Confusion matrix for Rosamerica S1-ONLY-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">75.96</td><td>1.92</td><td>0.0</td><td>3.85</td><td style="background-color:red">15.38</td><td>1.92</td><td>0.96</td></tr>
# <tr><th>dance</th><td>0.64</td><td style="background-color:green">69.17</td><td>5.61</td><td>0.13</td><td style="background-color:red">19.75</td><td>4.08</td><td>0.64</td></tr>
# <tr><th>hip hop</th><td>0.44</td><td>2.49</td><td style="background-color:green">78.45</td><td>0.29</td><td>8.5</td><td>8.65</td><td>1.17</td></tr>
# <tr><th>jazz</th><td style="background-color:red">14.91</td><td>1.34</td><td>1.21</td><td style="background-color:green">51.74</td><td style="background-color:red">18.85</td><td style="background-color:red">10.31</td><td>1.63</td></tr>
# <tr><th>pop</th><td>4.52</td><td>7.21</td><td>1.93</td><td>1.82</td><td style="background-color:green">63.27</td><td style="background-color:red">17.07</td><td>4.19</td></tr>
# <tr><th>rhythm and blues</th><td>2.22</td><td>2.87</td><td>7.58</td><td>2.35</td><td style="background-color:red">38.41</td><td style="background-color:green">45.07</td><td>1.5</td></tr>
# <tr><th>rock</th><td>5.3</td><td>2.5</td><td>1.24</td><td>1.78</td><td style="background-color:red">44.92</td><td>9.08</td><td style="background-color:green">35.17</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>47.25
# <br><b>Normalised accuracy: </b>59.83</p>
# <b>Confusion matrix for Rosamerica S1-ONLY-D2</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">75.96</td><td>1.92</td><td>0.0</td><td>3.85</td><td style="background-color:red">15.38</td><td>1.92</td><td>0.96</td></tr>
# <tr><th>dance</th><td>0.64</td><td style="background-color:green">69.17</td><td>5.61</td><td>0.13</td><td style="background-color:red">19.75</td><td>4.08</td><td>0.64</td></tr>
# <tr><th>hip hop</th><td>0.44</td><td>2.49</td><td style="background-color:green">78.45</td><td>0.29</td><td>8.5</td><td>8.65</td><td>1.17</td></tr>
# <tr><th>jazz</th><td style="background-color:red">14.91</td><td>1.34</td><td>1.21</td><td style="background-color:green">51.74</td><td style="background-color:red">18.85</td><td style="background-color:red">10.31</td><td>1.63</td></tr>
# <tr><th>pop</th><td>4.52</td><td>7.21</td><td>1.93</td><td>1.82</td><td style="background-color:green">63.27</td><td style="background-color:red">17.07</td><td>4.19</td></tr>
# <tr><th>rhythm and blues</th><td>2.22</td><td>2.87</td><td>7.58</td><td>2.35</td><td style="background-color:red">38.41</td><td style="background-color:green">45.07</td><td>1.5</td></tr>
# <tr><th>rock</th><td>5.3</td><td>2.5</td><td>1.24</td><td>1.78</td><td style="background-color:red">44.92</td><td>9.08</td><td style="background-color:green">35.17</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>51.53
# <br><b>Normalised accuracy: </b>52.38</p>
# <b>Confusion matrix for Rosamerica S1-ALL-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">66.2</td><td>2.82</td><td>0.0</td><td>3.52</td><td style="background-color:red">18.31</td><td>8.45</td><td>0.7</td></tr>
# <tr><th>dance</th><td>0.48</td><td style="background-color:green">52.57</td><td>6.52</td><td>0.41</td><td style="background-color:red">32.67</td><td>6.52</td><td>0.82</td></tr>
# <tr><th>hip hop</th><td>0.81</td><td>2.77</td><td style="background-color:green">72.72</td><td>0.23</td><td style="background-color:red">10.87</td><td style="background-color:red">10.52</td><td>2.08</td></tr>
# <tr><th>jazz</th><td style="background-color:red">13.3</td><td>1.62</td><td>2.01</td><td style="background-color:green">45.96</td><td style="background-color:red">21.8</td><td style="background-color:red">13.54</td><td>1.76</td></tr>
# <tr><th>pop</th><td>3.54</td><td>9.81</td><td>2.95</td><td>1.6</td><td style="background-color:green">59.84</td><td style="background-color:red">16.84</td><td>5.41</td></tr>
# <tr><th>rhythm and blues</th><td>2.31</td><td>3.95</td><td>8.29</td><td>3.59</td><td style="background-color:red">41.51</td><td style="background-color:green">38.52</td><td>1.83</td></tr>
# <tr><th>rock</th><td>4.96</td><td>2.96</td><td>1.46</td><td>1.83</td><td style="background-color:red">47.35</td><td style="background-color:red">10.58</td><td style="background-color:green">30.85</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>51.53
# <br><b>Normalised accuracy: </b>52.38</p>
# <b>Confusion matrix for Rosamerica S1-ALL-D2</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">66.2</td><td>2.82</td><td>0.0</td><td>3.52</td><td style="background-color:red">18.31</td><td>8.45</td><td>0.7</td></tr>
# <tr><th>dance</th><td>0.48</td><td style="background-color:green">52.57</td><td>6.52</td><td>0.41</td><td style="background-color:red">32.67</td><td>6.52</td><td>0.82</td></tr>
# <tr><th>hip hop</th><td>0.81</td><td>2.77</td><td style="background-color:green">72.72</td><td>0.23</td><td style="background-color:red">10.87</td><td style="background-color:red">10.52</td><td>2.08</td></tr>
# <tr><th>jazz</th><td style="background-color:red">13.3</td><td>1.62</td><td>2.01</td><td style="background-color:green">45.96</td><td style="background-color:red">21.8</td><td style="background-color:red">13.54</td><td>1.76</td></tr>
# <tr><th>pop</th><td>3.54</td><td>9.81</td><td>2.95</td><td>1.6</td><td style="background-color:green">59.84</td><td style="background-color:red">16.84</td><td>5.41</td></tr>
# <tr><th>rhythm and blues</th><td>2.31</td><td>3.95</td><td>8.29</td><td>3.59</td><td style="background-color:red">41.51</td><td style="background-color:green">38.52</td><td>1.83</td></tr>
# <tr><th>rock</th><td>4.96</td><td>2.96</td><td>1.46</td><td>1.83</td><td style="background-color:red">47.35</td><td style="background-color:red">10.58</td><td style="background-color:green">30.85</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>25.39
# <br><b>Normalised accuracy: </b>20.08</p>
# <b>Confusion matrix for Rosamerica S2-ONLY-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">82.05</td><td>0.0</td><td>0.0</td><td>5.13</td><td style="background-color:red">10.26</td><td>2.56</td><td>0.0</td></tr>
# <tr><th>dance</th><td>0.57</td><td style="background-color:green">50.57</td><td>9.2</td><td>0.0</td><td style="background-color:red">33.33</td><td>4.6</td><td>1.72</td></tr>
# <tr><th>hip hop</th><td>0.2</td><td>0.41</td><td style="background-color:green">86.21</td><td>0.2</td><td>6.29</td><td>6.49</td><td>0.2</td></tr>
# <tr><th>jazz</th><td style="background-color:red">14.83</td><td>0.88</td><td>0.67</td><td style="background-color:green">57.49</td><td style="background-color:red">16.33</td><td>8.66</td><td>1.14</td></tr>
# <tr><th>pop</th><td>3.91</td><td>6.33</td><td>2.0</td><td>1.17</td><td style="background-color:green">64.03</td><td style="background-color:red">17.65</td><td>4.91</td></tr>
# <tr><th>rhythm and blues</th><td>2.28</td><td>1.87</td><td>7.49</td><td>1.71</td><td style="background-color:red">38.76</td><td style="background-color:green">46.25</td><td>1.63</td></tr>
# <tr><th>rock</th><td>4.63</td><td>1.84</td><td>1.15</td><td>2.0</td><td style="background-color:red">45.27</td><td>9.98</td><td style="background-color:green">35.14</td></tr>
# <tr><th>electronic</th><td style="b
