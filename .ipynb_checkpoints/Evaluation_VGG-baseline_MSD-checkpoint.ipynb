# %% [markdown]
# # Cross-collection evaluation of the VGG baseline in the MTG-Jamendo test set

# %%
# %pylab inline
# %load_ext autoreload
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import csv
import collections
import json
import os

# %% [markdown]
# ## Evaluation strategies
# We consider different strategies for evaluation. These strategies are concerned with the mapping between the classes defined by the classifiers and the classes defined in our generated ground truth. A direct mapping is not possible for any of our classifiers.
#
# We want to know classifier performance given all music in a dataset, as well as its performance when only given the subset of music that it is aimed for:
# * __S1__ Use only recordings whose ground truth has a matching class in the classifier. For example, if a recording is only annotated with the class electronic, and this class does not appear in the classifier model, we discard it.
# * __S2__ Use all recordings in the ground truth and treat recordings from classes that do not exist in the model as an incorrect classification.
#
# Where the ground truth has more than one class for a track we consider different methods of matching these classes to classifiers’ estimates:
#  * __ONLY__: Only use recordings that have one ground-truth genre tag, and discard the rest of the recordings when computing evaluation metrics
#  * __ALL__: When a recording has more than one ground-truth genre, accept an estimate as correct if it matches any of these, even though for the rest of the genres it could be considered a misclassification.
#
#
# ### Duplicates
# As we have observed that duplicate recordings submitted to AcousticBrainz may have inconsistent genre es-
# timates as a result of different low-level descriptors, we consider two ways of dealing with them:
#  * __D1__ Remove all recordings that have duplicates from consideration
#  * __D2__ Treat all instances (recordings) in our data as independent, even if they are the same song.

# %% [markdown]
# # Mappings

# %% [markdown]
# The rosamerica -> our ground truth mapping. We discard the speech class as it has no match in our ground truth

# %%
rosamerica_gt_map = {
    'cla': ['classical'],
    'dan': ['dance'], # We listened to this dataset. It's all eurotrance (subgenre of electronic)
    'hip': ['hip hop'],
    'jaz': ['jazz'],
    'pop': ['pop'],
    'rhy': ['rhythm and blues'],
    'roc': ['rock'],
}

# %% [markdown]
# Tzanetakis groundtruth mapping. We discard disco as there is no clear match to our ground truth (the class in the dataset contains both electronic disco and non-electronic funk/soul-type disco. We are not sure if we should match it to electronic or rhythm and blues. We don't have a separate top-level genre for metal so we map both metal and rock to rock.

# %%
tzanetakis_gt_map = {
    'blu': ['blues'],
    'cla': ['classical'],
    'cou': ['country'],
    'dis': ['disco'], #disco - electronic & acoustic soul
    'hip': ['hip hop'],
    'jaz': ['jazz'],
    'met': ['metal'],
    'pop': ['pop'],
    'reg': ['reggae'], # reggae, in our gt a subgenre of ska
    'roc': ['rock']
}

# %% [markdown]
# Dortmund groundtruth mapping. Both alternative and rock are mapped to rock. folkcountry is mapped to both folk and country.

# %%
dortmund_gt_map = {
    'alternative': ['alternative rock'], # alternative rock is a subgenre of rock
    'blues': ['blues'],
    'electronic': ['electronic'],
    'folkcountry': ['country'],
    'funksoulrnb': ['rhythm and blues'],
    'jazz': ['jazz'],
    'pop': ['pop'],
    'raphiphop': ['hip hop'],
    'rock': ['rock']
}

# %%
import genreeval

ground_truth = "lastfm-audio-genres-clean.json"

ros = ("Rosamerica", "predictions/msd/lastfm-test_vgg-baseline_rosamerica.json", rosamerica_gt_map)
dor = ("Dortmund", "predictions/msd/lastfm-test_vgg-baseline_dortmund.json", dortmund_gt_map)
tza = ("Tzanetakis", "predictions/msd/lastfm-test_vgg-baseline_tzanetakis.json", tzanetakis_gt_map)

res = {}
for name, filename, gtmap in [ros, dor, tza]:
    res[name] = genreeval.run_evaluations(ground_truth, gtmap, filename, name, "Evaluation")[name]
# Out:
# RUNNING EVALUATION: Rosamerica S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16499 complete
#
# RUNNING EVALUATION: Rosamerica S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16499 complete
#
# RUNNING EVALUATION: Rosamerica S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 13766 complete
#
# RUNNING EVALUATION: Rosamerica S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S1 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 13766 complete
#
# RUNNING EVALUATION: Rosamerica S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Rosamerica S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Rosamerica S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Rosamerica S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Rosamerica - S2 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Dortmund S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 23229 complete
#  [                  0%                  ]  20001 of 23229 complete
#
# RUNNING EVALUATION: Dortmund S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 23229 complete
#  [                  0%                  ]  20001 of 23229 complete
#
# RUNNING EVALUATION: Dortmund S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16889 complete
#
# RUNNING EVALUATION: Dortmund S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S1 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16889 complete
#
# RUNNING EVALUATION: Dortmund S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Dortmund S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Dortmund S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Dortmund S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Dortmund - S2 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 17698 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 17698 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 14941 complete
#
# RUNNING EVALUATION: Tzanetakis S1 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S1 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 14941 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ALL D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ALL - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ALL D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ALL - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 25515 complete
#  [                  0%                  ]  20001 of 25515 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ONLY D1
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ONLY - D1
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete
#
# RUNNING EVALUATION: Tzanetakis S2 ONLY D2
# Loading estimates...
# done
# Loading ground truth...
# done
# Tzanetakis - S2 - ONLY - D2
#  [                  0%                  ]
#  [                  0%                  ]  10001 of 16385 complete

# %%
output = ""
from IPython.display import HTML
for classifier in ["Rosamerica", "Dortmund", "Tzanetakis"]:
    output += "<h1>%s</h1>" % classifier
    for strat in ["S1", "S2"]:
        for var in ["ONLY", "ALL"]: #"FIRST"
            for d in ["D1", "D2"]:
                results = res[classifier][strat][var][d]
                results.save("results")
                #fname = "%s.csv" % results.name.lower().replace(" ", "").replace(",", "-")
                #results.confusion_matrix.to_csv(fname)
                output += "<h2>%s</h2>\n" % (results.data['name'], )
                output += "<p><b>Raw accuracy: </b>%s\n" % results.raw_accuracy
                output += "<br><b>Normalised accuracy: </b>%s</p>\n" % results.normalised_accuracy
                output += results.html + "\n\n"
HTML(output)
# Out:
# <h1>Rosamerica</h1><h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>55.68
# <br><b>Normalised accuracy: </b>51.62</p>
# <b>Confusion matrix for Rosamerica S1-ONLY-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">66.35</td><td style="background-color:red">17.31</td><td>0.96</td><td>0.96</td><td>4.81</td><td>0.0</td><td>9.62</td></tr>
# <tr><th>dance</th><td>0.64</td><td style="background-color:green">76.43</td><td>3.82</td><td>0.13</td><td style="background-color:red">11.08</td><td>0.51</td><td>7.39</td></tr>
# <tr><th>hip hop</th><td>0.3</td><td>9.32</td><td style="background-color:green">66.27</td><td>0.59</td><td style="background-color:red">11.98</td><td>0.59</td><td style="background-color:red">10.95</td></tr>
# <tr><th>jazz</th><td style="background-color:red">15.8</td><td style="background-color:red">16.72</td><td>0.8</td><td style="background-color:green">37.64</td><td style="background-color:red">15.3</td><td>1.51</td><td style="background-color:red">12.24</td></tr>
# <tr><th>pop</th><td>7.82</td><td style="background-color:red">17.9</td><td>1.87</td><td>1.76</td><td style="background-color:green">29.35</td><td>1.54</td><td style="background-color:red">39.76</td></tr>
# <tr><th>rhythm and blues</th><td>3.92</td><td style="background-color:red">14.58</td><td>8.63</td><td>3.27</td><td style="background-color:red">39.9</td><td style="background-color:green">8.04</td><td style="background-color:red">21.65</td></tr>
# <tr><th>rock</th><td>5.46</td><td>7.37</td><td>0.59</td><td>1.71</td><td>7.34</td><td>0.28</td><td style="background-color:green">77.26</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>55.68
# <br><b>Normalised accuracy: </b>51.62</p>
# <b>Confusion matrix for Rosamerica S1-ONLY-D2</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">66.35</td><td style="background-color:red">17.31</td><td>0.96</td><td>0.96</td><td>4.81</td><td>0.0</td><td>9.62</td></tr>
# <tr><th>dance</th><td>0.64</td><td style="background-color:green">76.43</td><td>3.82</td><td>0.13</td><td style="background-color:red">11.08</td><td>0.51</td><td>7.39</td></tr>
# <tr><th>hip hop</th><td>0.3</td><td>9.32</td><td style="background-color:green">66.27</td><td>0.59</td><td style="background-color:red">11.98</td><td>0.59</td><td style="background-color:red">10.95</td></tr>
# <tr><th>jazz</th><td style="background-color:red">15.8</td><td style="background-color:red">16.72</td><td>0.8</td><td style="background-color:green">37.64</td><td style="background-color:red">15.3</td><td>1.51</td><td style="background-color:red">12.24</td></tr>
# <tr><th>pop</th><td>7.82</td><td style="background-color:red">17.9</td><td>1.87</td><td>1.76</td><td style="background-color:green">29.35</td><td>1.54</td><td style="background-color:red">39.76</td></tr>
# <tr><th>rhythm and blues</th><td>3.92</td><td style="background-color:red">14.58</td><td>8.63</td><td>3.27</td><td style="background-color:red">39.9</td><td style="background-color:green">8.04</td><td style="background-color:red">21.65</td></tr>
# <tr><th>rock</th><td>5.46</td><td>7.37</td><td>0.59</td><td>1.71</td><td>7.34</td><td>0.28</td><td style="background-color:green">77.26</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>57.55
# <br><b>Normalised accuracy: </b>46.43</p>
# <b>Confusion matrix for Rosamerica S1-ALL-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">60.56</td><td style="background-color:red">18.31</td><td>0.7</td><td>0.7</td><td>7.75</td><td>0.0</td><td style="background-color:red">11.97</td></tr>
# <tr><th>dance</th><td>0.41</td><td style="background-color:green">63.69</td><td>6.52</td><td>0.34</td><td style="background-color:red">17.3</td><td>0.48</td><td style="background-color:red">11.26</td></tr>
# <tr><th>hip hop</th><td>0.47</td><td style="background-color:red">11.44</td><td style="background-color:green">60.33</td><td>0.47</td><td style="background-color:red">14.7</td><td>0.93</td><td style="background-color:red">11.67</td></tr>
# <tr><th>jazz</th><td style="background-color:red">14.18</td><td style="background-color:red">17.15</td><td>1.55</td><td style="background-color:green">33.7</td><td style="background-color:red">18.0</td><td>1.76</td><td style="background-color:red">13.66</td></tr>
# <tr><th>pop</th><td>6.11</td><td style="background-color:red">20.18</td><td>3.57</td><td>1.76</td><td style="background-color:green">26.68</td><td>1.42</td><td style="background-color:red">40.28</td></tr>
# <tr><th>rhythm and blues</th><td>4.07</td><td style="background-color:red">16.45</td><td>9.82</td><td>3.83</td><td style="background-color:red">39.64</td><td style="background-color:green">6.07</td><td style="background-color:red">20.12</td></tr>
# <tr><th>rock</th><td>5.5</td><td>8.31</td><td>0.89</td><td>1.83</td><td>9.1</td><td>0.39</td><td style="background-color:green">73.97</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>57.55
# <br><b>Normalised accuracy: </b>46.43</p>
# <b>Confusion matrix for Rosamerica S1-ALL-D2</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">60.56</td><td style="background-color:red">18.31</td><td>0.7</td><td>0.7</td><td>7.75</td><td>0.0</td><td style="background-color:red">11.97</td></tr>
# <tr><th>dance</th><td>0.41</td><td style="background-color:green">63.69</td><td>6.52</td><td>0.34</td><td style="background-color:red">17.3</td><td>0.48</td><td style="background-color:red">11.26</td></tr>
# <tr><th>hip hop</th><td>0.47</td><td style="background-color:red">11.44</td><td style="background-color:green">60.33</td><td>0.47</td><td style="background-color:red">14.7</td><td>0.93</td><td style="background-color:red">11.67</td></tr>
# <tr><th>jazz</th><td style="background-color:red">14.18</td><td style="background-color:red">17.15</td><td>1.55</td><td style="background-color:green">33.7</td><td style="background-color:red">18.0</td><td>1.76</td><td style="background-color:red">13.66</td></tr>
# <tr><th>pop</th><td>6.11</td><td style="background-color:red">20.18</td><td>3.57</td><td>1.76</td><td style="background-color:green">26.68</td><td>1.42</td><td style="background-color:red">40.28</td></tr>
# <tr><th>rhythm and blues</th><td>4.07</td><td style="background-color:red">16.45</td><td>9.82</td><td>3.83</td><td style="background-color:red">39.64</td><td style="background-color:green">6.07</td><td style="background-color:red">20.12</td></tr>
# <tr><th>rock</th><td>5.5</td><td>8.31</td><td>0.89</td><td>1.83</td><td>9.1</td><td>0.39</td><td style="background-color:green">73.97</td></tr></table>
#
# <h2>Rosamerica</h2>
# <p><b>Raw accuracy: </b>26.55
# <br><b>Normalised accuracy: </b>17.84</p>
# <b>Confusion matrix for Rosamerica S2-ONLY-D1</b><table><tr><td></td><th>classical</th><th>dance</th><th>hip hop</th><th>jazz</th><th>pop</th><th>rhythm and blues</th><th>rock</th></tr><tr><th>classical</th><td style="background-color:green">79.49</td><td style="background-color:red">12.82</td><td>0.0</td><td>2.56</td><td>2.56</td><td>0.0</td><td>2.56</td></tr>
# <tr><th>dance</th><td>0.58</td><td style="background-color:green">63.58</td><td>4.62</td><td>0.0</td><td style="background-color:red">18.5</td><td>0.58</td><td style="background-color:red">12.14</td></tr>
# <tr><th>hip hop</th><td>0.0</td><td>6.97</td><td style="background-color:green">73.36</td><td>0.41</td><td style="background-color:red">11.07</td><td>0.61</td><td>7.58</td></tr>
# <tr><th>jazz</th><td style="background-color:red">15.66</td><td style="background-color:red">16.07</td><td>0.31</td><td style="b
